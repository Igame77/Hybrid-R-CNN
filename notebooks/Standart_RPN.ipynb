# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from ipywidgets import IntProgress
import os
import cv2
import PIL
import PIL.Image
import json
import random
from random import randint as rand
from os import listdir
from os.path import isfile, join
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# []

# %%
import random
import tensorflow as tf
import matplotlib.image as mpimg
import numpy as np


def generator():
    path = r'C:\Users\Ильяс\.cache\roboflow\PPE.v14i.yolokeras\update__annotations.txt'
    data = open(path, 'r').readlines()
    for el in data:
        path_image = el.replace('\n', '')
        path_label = (
            'C:\\Users\\Ильяс\\.cache\\roboflow\\PPE.v14i.yolokeras\\train\\labels\\'
            + path_image.split('\\')[-1].replace('\n', '') + '.txt'
        )

        bbox = []
        try:
            with open(path_label, 'r') as f:
                label = f.readlines()

            for e in label:
                if len(e) <= 1:
                    continue
                li = e.split()[1:]
                if len(li) < 4:
                    continue

                # Лейблы уже в формате x1, y1, x2, y2 (нормализованные 0..1) -> домножаем на 224
                x1 = float(li[0]) 
                y1 = float(li[1])
                x2 = float(li[2]) 
                y2 = float(li[3])
                w = x2-x1
                h=y2-y1

                x=(x1+x2)/2
                y=(y1+y2)/2
                x1=x
                y1=y
                x2=w
                y2=h
                

                bbox.append([x1, y1, x2, y2])
                if len(bbox) >= 50:
                    break
        except FileNotFoundError:
            continue

        try:
            image = tf.image.resize(
                tf.cast(mpimg.imread(path_image), tf.float32),
                (224, 224)
            ) / 255.0
        except Exception as e:
            continue

        if len(bbox) == 0:
            continue

        # Пока ротация только 0, поэтому боксы не меняем
        rotation = random.choice([0])
        rotated_image = tf.image.rot90(image, k=rotation)

        rotated_bbox = []
        for box in bbox:
            x1, y1, x2, y2 = box

            if rotation == 1:
                # ПРИМЕР (если будете включать ротацию 90°):
                # new_x1 = y1
                # new_y1 = 224 - x2
                # new_x2 = y2
                # new_y2 = 224 - x1
                # здесь можно дописать реальную логику, пока rotation=0 это не используется
                new_x1, new_y1, new_x2, new_y2 = x1, y1, x2, y2
            elif rotation == 2:
                # Аналогично, можно реализовать поворот на 180°
                new_x1, new_y1, new_x2, new_y2 = x1, y1, x2, y2
            elif rotation == 3:
                # Аналогично, поворот на 270°
                new_x1, new_y1, new_x2, new_y2 = x1, y1, x2, y2
            else:
                new_x1, new_y1, new_x2, new_y2 = x1, y1, x2, y2

            # Добавляем флаг 0 для GT боксов
            rotated_bbox.append([new_x1, new_y1, new_x2, new_y2, 0.0])

        

        all_boxes = rotated_bbox 

        yield (rotated_image, tf.constant(all_boxes, dtype=tf.float32))
def valid_generator():
    path = r'C:\Users\Ильяс\.cache\roboflow\PPE.v14i.yolokeras\update_test_annotations.txt'
    data = open(path, 'r').readlines()
    for el in data:
        path_image = el.replace('\n', '')
        path_label = (
            'C:\\Users\\Ильяс\\.cache\\roboflow\\PPE.v14i.yolokeras\\test\\labels\\'
            + path_image.split('\\')[-1].replace('\n', '') + '.txt'
        )

        bbox = []
        try:
            with open(path_label, 'r') as f:
                label = f.readlines()

            for e in label:
                if len(e) <= 1:
                    continue
                li = e.split()[1:]
                if len(li) < 4:
                    continue

                # Формат x1, y1, x2, y2 (нормализованные) -> домножаем на 224
                x1 = float(li[0]) 
                y1 = float(li[1]) 
                x2 = float(li[2]) 
                y2 = float(li[3]) 
                w=x2-x1
                h=y2-y1

                x=(x1+x2)/2
                y=(y1+y2)/2
                x1=x
                y1=y
                x2=w
                y2=h

                bbox.append([x1, y1, x2, y2])
                if len(bbox) >= 50:
                    break
        except FileNotFoundError:
            continue

        try:
            image = tf.image.resize(
                tf.cast(mpimg.imread(path_image), tf.float32),
                (224, 224)
            ) / 255.0
        except Exception as e:
            continue

        if len(bbox) == 0:
            continue

        # Добавляем флаг 0 для GT боксов в валидационном наборе
        bbox_with_flag = [[x1, y1, x2, y2, 0.0] for x1, y1, x2, y2 in bbox]

        yield (image, tf.constant(bbox_with_flag, dtype=tf.float32))
# Создаем datasets для одиночных примеров
dataset = tf.data.Dataset.from_generator(
    generator,
    output_signature=(
        tf.TensorSpec(shape=(224, 224, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, 5), dtype=tf.float32)  # [x1, y1, x2, y2, flag]
    )
)

valid_dataset = tf.data.Dataset.from_generator(
    valid_generator,
    output_signature=(
        tf.TensorSpec(shape=(224, 224, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, 5), dtype=tf.float32)  # [x1, y1, x2, y2, flag]
    )
)

# Кэшируем и перемешиваем (БЕЗ .batch()!)
dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE).shuffle(100)
valid_dataset = valid_dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
backbone_encoder = tf.keras.models.load_model(
    r'models/base_classifier.h5', 
    compile=False,
)

# %%
output_tensor = backbone_encoder.output
clipped_model = tf.keras.Model(backbone_encoder.input, output_tensor)

# %%
clipped_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 112, 112, 32)      │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 112, 112, 32)      │             128 │ Conv1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1_relu (ReLU)             │ (None, 112, 112, 32)      │               0 │ bn_Conv1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise       │ (None, 112, 112, 32)      │             288 │ Conv1_relu[0][0]           │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_BN    │ (None, 112, 112, 32)      │             128 │ expanded_conv_depthwise[0… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_relu  │ (None, 112, 112, 32)      │               0 │ expanded_conv_depthwise_B… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project         │ (None, 112, 112, 16)      │             512 │ expanded_conv_depthwise_r… │
# │ (Conv2D)                      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project_BN      │ (None, 112, 112, 16)      │              64 │ expanded_conv_project[0][… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand (Conv2D)       │ (None, 112, 112, 96)      │           1,536 │ expanded_conv_project_BN[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_BN             │ (None, 112, 112, 96)      │             384 │ block_1_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_relu (ReLU)    │ (None, 112, 112, 96)      │               0 │ block_1_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_pad (ZeroPadding2D)   │ (None, 113, 113, 96)      │               0 │ block_1_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise             │ (None, 56, 56, 96)        │             864 │ block_1_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_BN          │ (None, 56, 56, 96)        │             384 │ block_1_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_relu (ReLU) │ (None, 56, 56, 96)        │               0 │ block_1_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project (Conv2D)      │ (None, 56, 56, 24)        │           2,304 │ block_1_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project_BN            │ (None, 56, 56, 24)        │              96 │ block_1_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand (Conv2D)       │ (None, 56, 56, 144)       │           3,456 │ block_1_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_BN             │ (None, 56, 56, 144)       │             576 │ block_2_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_relu (ReLU)    │ (None, 56, 56, 144)       │               0 │ block_2_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise             │ (None, 56, 56, 144)       │           1,296 │ block_2_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_BN          │ (None, 56, 56, 144)       │             576 │ block_2_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_relu (ReLU) │ (None, 56, 56, 144)       │               0 │ block_2_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project (Conv2D)      │ (None, 56, 56, 24)        │           3,456 │ block_2_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project_BN            │ (None, 56, 56, 24)        │              96 │ block_2_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_add (Add)             │ (None, 56, 56, 24)        │               0 │ block_1_project_BN[0][0],  │
# │                               │                           │                 │ block_2_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand (Conv2D)       │ (None, 56, 56, 144)       │           3,456 │ block_2_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_BN             │ (None, 56, 56, 144)       │             576 │ block_3_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_relu (ReLU)    │ (None, 56, 56, 144)       │               0 │ block_3_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_pad (ZeroPadding2D)   │ (None, 57, 57, 144)       │               0 │ block_3_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise             │ (None, 28, 28, 144)       │           1,296 │ block_3_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_BN          │ (None, 28, 28, 144)       │             576 │ block_3_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_relu (ReLU) │ (None, 28, 28, 144)       │               0 │ block_3_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project (Conv2D)      │ (None, 28, 28, 32)        │           4,608 │ block_3_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project_BN            │ (None, 28, 28, 32)        │             128 │ block_3_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand (Conv2D)       │ (None, 28, 28, 192)       │           6,144 │ block_3_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_BN             │ (None, 28, 28, 192)       │             768 │ block_4_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_relu (ReLU)    │ (None, 28, 28, 192)       │               0 │ block_4_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise             │ (None, 28, 28, 192)       │           1,728 │ block_4_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_BN          │ (None, 28, 28, 192)       │             768 │ block_4_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_relu (ReLU) │ (None, 28, 28, 192)       │               0 │ block_4_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project (Conv2D)      │ (None, 28, 28, 32)        │           6,144 │ block_4_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project_BN            │ (None, 28, 28, 32)        │             128 │ block_4_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_add (Add)             │ (None, 28, 28, 32)        │               0 │ block_3_project_BN[0][0],  │
# │                               │                           │                 │ block_4_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand (Conv2D)       │ (None, 28, 28, 192)       │           6,144 │ block_4_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_BN             │ (None, 28, 28, 192)       │             768 │ block_5_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_relu (ReLU)    │ (None, 28, 28, 192)       │               0 │ block_5_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise             │ (None, 28, 28, 192)       │           1,728 │ block_5_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_BN          │ (None, 28, 28, 192)       │             768 │ block_5_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_relu (ReLU) │ (None, 28, 28, 192)       │               0 │ block_5_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project (Conv2D)      │ (None, 28, 28, 32)        │           6,144 │ block_5_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project_BN            │ (None, 28, 28, 32)        │             128 │ block_5_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_add (Add)             │ (None, 28, 28, 32)        │               0 │ block_4_add[0][0],         │
# │                               │                           │                 │ block_5_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand (Conv2D)       │ (None, 28, 28, 192)       │           6,144 │ block_5_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_BN             │ (None, 28, 28, 192)       │             768 │ block_6_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_relu (ReLU)    │ (None, 28, 28, 192)       │               0 │ block_6_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_pad (ZeroPadding2D)   │ (None, 29, 29, 192)       │               0 │ block_6_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise             │ (None, 14, 14, 192)       │           1,728 │ block_6_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_BN          │ (None, 14, 14, 192)       │             768 │ block_6_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_relu (ReLU) │ (None, 14, 14, 192)       │               0 │ block_6_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project (Conv2D)      │ (None, 14, 14, 64)        │          12,288 │ block_6_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project_BN            │ (None, 14, 14, 64)        │             256 │ block_6_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand (Conv2D)       │ (None, 14, 14, 384)       │          24,576 │ block_6_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_BN             │ (None, 14, 14, 384)       │           1,536 │ block_7_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_relu (ReLU)    │ (None, 14, 14, 384)       │               0 │ block_7_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise             │ (None, 14, 14, 384)       │           3,456 │ block_7_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_BN          │ (None, 14, 14, 384)       │           1,536 │ block_7_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_relu (ReLU) │ (None, 14, 14, 384)       │               0 │ block_7_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project (Conv2D)      │ (None, 14, 14, 64)        │          24,576 │ block_7_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project_BN            │ (None, 14, 14, 64)        │             256 │ block_7_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_add (Add)             │ (None, 14, 14, 64)        │               0 │ block_6_project_BN[0][0],  │
# │                               │                           │                 │ block_7_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand (Conv2D)       │ (None, 14, 14, 384)       │          24,576 │ block_7_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_BN             │ (None, 14, 14, 384)       │           1,536 │ block_8_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_relu (ReLU)    │ (None, 14, 14, 384)       │               0 │ block_8_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise             │ (None, 14, 14, 384)       │           3,456 │ block_8_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_BN          │ (None, 14, 14, 384)       │           1,536 │ block_8_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_relu (ReLU) │ (None, 14, 14, 384)       │               0 │ block_8_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project (Conv2D)      │ (None, 14, 14, 64)        │          24,576 │ block_8_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project_BN            │ (None, 14, 14, 64)        │             256 │ block_8_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_add (Add)             │ (None, 14, 14, 64)        │               0 │ block_7_add[0][0],         │
# │                               │                           │                 │ block_8_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand (Conv2D)       │ (None, 14, 14, 384)       │          24,576 │ block_8_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_BN             │ (None, 14, 14, 384)       │           1,536 │ block_9_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_relu (ReLU)    │ (None, 14, 14, 384)       │               0 │ block_9_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise             │ (None, 14, 14, 384)       │           3,456 │ block_9_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_BN          │ (None, 14, 14, 384)       │           1,536 │ block_9_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_relu (ReLU) │ (None, 14, 14, 384)       │               0 │ block_9_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project (Conv2D)      │ (None, 14, 14, 64)        │          24,576 │ block_9_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project_BN            │ (None, 14, 14, 64)        │             256 │ block_9_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_add (Add)             │ (None, 14, 14, 64)        │               0 │ block_8_add[0][0],         │
# │                               │                           │                 │ block_9_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand (Conv2D)      │ (None, 14, 14, 384)       │          24,576 │ block_9_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_BN            │ (None, 14, 14, 384)       │           1,536 │ block_10_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_relu (ReLU)   │ (None, 14, 14, 384)       │               0 │ block_10_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise            │ (None, 14, 14, 384)       │           3,456 │ block_10_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_BN         │ (None, 14, 14, 384)       │           1,536 │ block_10_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_relu       │ (None, 14, 14, 384)       │               0 │ block_10_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project (Conv2D)     │ (None, 14, 14, 96)        │          36,864 │ block_10_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project_BN           │ (None, 14, 14, 96)        │             384 │ block_10_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand (Conv2D)      │ (None, 14, 14, 576)       │          55,296 │ block_10_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_BN            │ (None, 14, 14, 576)       │           2,304 │ block_11_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_relu (ReLU)   │ (None, 14, 14, 576)       │               0 │ block_11_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise            │ (None, 14, 14, 576)       │           5,184 │ block_11_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_BN         │ (None, 14, 14, 576)       │           2,304 │ block_11_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_relu       │ (None, 14, 14, 576)       │               0 │ block_11_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project (Conv2D)     │ (None, 14, 14, 96)        │          55,296 │ block_11_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project_BN           │ (None, 14, 14, 96)        │             384 │ block_11_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_add (Add)            │ (None, 14, 14, 96)        │               0 │ block_10_project_BN[0][0], │
# │                               │                           │                 │ block_11_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand (Conv2D)      │ (None, 14, 14, 576)       │          55,296 │ block_11_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_BN            │ (None, 14, 14, 576)       │           2,304 │ block_12_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_relu (ReLU)   │ (None, 14, 14, 576)       │               0 │ block_12_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise            │ (None, 14, 14, 576)       │           5,184 │ block_12_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_BN         │ (None, 14, 14, 576)       │           2,304 │ block_12_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_relu       │ (None, 14, 14, 576)       │               0 │ block_12_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project (Conv2D)     │ (None, 14, 14, 96)        │          55,296 │ block_12_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project_BN           │ (None, 14, 14, 96)        │             384 │ block_12_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_add (Add)            │ (None, 14, 14, 96)        │               0 │ block_11_add[0][0],        │
# │                               │                           │                 │ block_12_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand (Conv2D)      │ (None, 14, 14, 576)       │          55,296 │ block_12_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_BN            │ (None, 14, 14, 576)       │           2,304 │ block_13_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_relu (ReLU)   │ (None, 14, 14, 576)       │               0 │ block_13_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_pad (ZeroPadding2D)  │ (None, 15, 15, 576)       │               0 │ block_13_expand_relu[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 7, 7, 576)         │               0 │ block_13_pad[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ resizing (Resizing)           │ (None, 7, 7, 576)         │               0 │ block_13_pad[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 7, 7, 1152)        │               0 │ max_pooling2d[0][0],       │
# │                               │                           │                 │ resizing[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 616,256 (2.35 MB)
#  Trainable params: 334,272 (1.28 MB)
#  Non-trainable params: 281,984 (1.08 MB)

# %%
X = []
y = []

for el in dataset:
    X.append(clipped_model.predict(tf.expand_dims(el[0], axis = 0), verbose = 0))
    y.append(el[1][:, :-1])

X = np.array(X)

# %%
y = np.array(y, dtype=object)

# %%
y = y.reshape(y.shape[0], -1)

# %%
y = [el[0].numpy().flatten() for el in y]

# %%
max_len = max(len(el) for el in y)

# %%
y_padded = []
for arr in y:
    pad_size = max_len - len(arr)
    padded = np.pad(arr, (0, pad_size), mode='constant', constant_values=0)
    y_padded.append(padded)

y = np.array(y_padded)

# %%
y.shape
# Out:
# (3725, 200)

# %%
X_val = []
y_val = []
for el in valid_dataset:
    X_val.append(clipped_model.predict(tf.expand_dims(el[0], axis = 0), verbose = 0))
    y_val.append(el[1][:, :-1])

X_val = np.array(X_val)

# %%
y_val = np.array(y_val, dtype = np.object_)

# %%
y_val = y_val.reshape(y_val.shape[0], -1)

# %%
y_val = [el[0].numpy().flatten() for el in y_val]

# %%
y_padded = []
for arr in y_val:
    pad_size = max_len - len(arr)
    padded = np.pad(arr, (0, pad_size), mode='constant', constant_values=0)
    y_padded.append(padded)

y_val = np.array(y_padded)

# %%
X = np.squeeze(X, axis=1)       
X_val = np.squeeze(X_val, axis=1)

# %%
def masked_ciou_loss(y_true, y_pred):

    true_boxes = tf.reshape(y_true, (-1, 50, 4))
    pred_boxes = tf.reshape(y_pred, (-1, 50, 4))


    mask = tf.cast(tf.reduce_sum(tf.abs(true_boxes), axis=-1) > 0.0001, tf.float32)
    mask = tf.expand_dims(mask, axis=-1)

    gt_cx, gt_cy, gt_w, gt_h = tf.unstack(true_boxes, axis=-1)
    p_cx, p_cy, p_w, p_h = tf.unstack(pred_boxes, axis=-1)

    gt_x1 = gt_cx - gt_w / 2.0
    gt_y1 = gt_cy - gt_h / 2.0
    gt_x2 = gt_cx + gt_w / 2.0
    gt_y2 = gt_cy + gt_h / 2.0

    p_x1 = p_cx - p_w / 2.0
    p_y1 = p_cy - p_h / 2.0
    p_x2 = p_cx + p_w / 2.0
    p_y2 = p_cy + p_h / 2.0

    inter_x1 = tf.maximum(gt_x1, p_x1)
    inter_y1 = tf.maximum(gt_y1, p_y1)
    inter_x2 = tf.minimum(gt_x2, p_x2)
    inter_y2 = tf.minimum(gt_y2, p_y2)

    inter_w = tf.maximum(0.0, inter_x2 - inter_x1)
    inter_h = tf.maximum(0.0, inter_y2 - inter_y1)
    inter_area = inter_w * inter_h

    gt_area = gt_w * gt_h
    p_area = p_w * p_h
    union_area = gt_area + p_area - inter_area + 1e-7

    iou = inter_area / union_area

    c_x1 = tf.minimum(gt_x1, p_x1)
    c_y1 = tf.minimum(gt_y1, p_y1)
    c_x2 = tf.maximum(gt_x2, p_x2)
    c_y2 = tf.maximum(gt_y2, p_y2)
    
    c_diag = tf.square(c_x2 - c_x1) + tf.square(c_y2 - c_y1) + 1e-7
    rho2 = tf.square(gt_cx - p_cx) + tf.square(gt_cy - p_cy)
    diou = rho2 / c_diag


    w_h_ratio_gt = tf.atan(gt_w / (gt_h + 1e-7))
    w_h_ratio_pred = tf.atan(p_w / (p_h + 1e-7))
    
    v = (4.0 / (math.pi ** 2)) * tf.square(w_h_ratio_gt - w_h_ratio_pred)
    
    alpha = v / (1.0 - iou + v + 1e-7)
    
    ciou_val = iou - diou - (alpha * v)
    
    ciou_loss_val = 1.0 - ciou_val
    

    obj_loss = ciou_loss_val * tf.squeeze(mask, axis=-1)


    no_obj_mask = 1.0 - mask
    
    silence_loss = tf.reduce_sum(tf.square(pred_boxes), axis=-1) 
    silence_loss = silence_loss * tf.squeeze(no_obj_mask, axis=-1)

    silence_weight = 0.6 
    
    total_loss = tf.reduce_sum(obj_loss) + silence_weight * tf.reduce_sum(silence_loss)
    
    num_objects = tf.reduce_sum(mask) + 1.0
    
    return total_loss / num_objects



def create_ciou_mlp():
    feat_in  = tf.keras.Input(shape=(7,7,1152), name="feat")

    ridge_in = tf.keras.layers.GlobalAveragePooling2D()(feat_in)
    ridge_dense = tf.keras.layers.Dense(200, use_bias=None, activation=None)
    ridge_in =  ridge_dense(ridge_in)
    ridge_emb = tf.keras.layers.Dense(32, activation='relu')(ridge_in)

    x = tf.keras.layers.Conv2D(128, 1, activation="relu")(feat_in)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    

    x = tf.keras.layers.Concatenate(axis=-1)([x, ridge_emb])

    x = tf.keras.layers.Dense(200, activation = 'sigmoid')(x)

    
    
    model = tf.keras.Model(feat_in, x)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss=masked_ciou_loss)

    
    return model




y_train_padded = y 
model = create_ciou_mlp()
history = model.fit(
    X, y,
    validation_data=(X_val, y_val),
    batch_size=32,
    epochs=1000,
    
)
# Out:
# Epoch 1/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.5320 - val_loss: 0.8789
# Epoch 2/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0891 - val_loss: 0.9068
# Epoch 3/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0733 - val_loss: 0.8644
# Epoch 4/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0638 - val_loss: 0.9430
# Epoch 5/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0380 - val_loss: 0.9280
# Epoch 6/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0348 - val_loss: 0.8979
# Epoch 7/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.0048 - val_loss: 0.8814
# Epoch 8/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9902 - val_loss: 0.8672
# Epoch 9/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9663 - val_loss: 0.9034
# Epoch 10/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9707 - val_loss: 0.7978
# Epoch 11/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9508 - val_loss: 0.7999
# Epoch 12/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9338 - val_loss: 0.7930
# Epoch 13/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9306 - val_loss: 0.7779
# Epoch 14/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9159 - val_loss: 0.7724
# Epoch 15/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9015 - val_loss: 0.7733
# Epoch 16/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8999 - val_loss: 0.7882
# Epoch 17/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8951 - val_loss: 0.7658
# Epoch 18/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8836 - val_loss: 0.7625
# Epoch 19/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8751 - val_loss: 0.7885
# Epoch 20/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8667 - val_loss: 0.7658
# Epoch 21/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8591 - val_loss: 0.7487
# Epoch 22/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8630 - val_loss: 0.7680
# Epoch 23/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8556 - val_loss: 0.7430
# Epoch 24/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8456 - val_loss: 0.7042
# Epoch 25/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8291 - val_loss: 0.7496
# Epoch 26/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8292 - val_loss: 0.7504
# Epoch 27/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8231 - val_loss: 0.7248
# Epoch 28/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8260 - val_loss: 0.7439
# Epoch 29/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8163 - val_loss: 0.7071
# Epoch 30/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8138 - val_loss: 0.6979
# Epoch 31/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.8081 - val_loss: 0.7075
# Epoch 32/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7995 - val_loss: 0.6834
# Epoch 33/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7968 - val_loss: 0.6948
# Epoch 34/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7972 - val_loss: 0.7178
# Epoch 35/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7960 - val_loss: 0.6963
# Epoch 36/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7928 - val_loss: 0.6865
# Epoch 37/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7875 - val_loss: 0.7004
# Epoch 38/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7880 - val_loss: 0.6596
# Epoch 39/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7850 - val_loss: 0.6723
# Epoch 40/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7754 - val_loss: 0.6930
# Epoch 41/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7710 - val_loss: 0.6661
# Epoch 42/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7622 - val_loss: 0.6780
# Epoch 43/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7609 - val_loss: 0.7313
# Epoch 44/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7654 - val_loss: 0.7059
# Epoch 45/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7575 - val_loss: 0.6880
# Epoch 46/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7622 - val_loss: 0.6584
# Epoch 47/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7524 - val_loss: 0.6820
# Epoch 48/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7571 - val_loss: 0.6639
# Epoch 49/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7481 - val_loss: 0.6842
# Epoch 50/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7472 - val_loss: 0.6837
# Epoch 51/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7540 - val_loss: 0.6648
# Epoch 52/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7463 - val_loss: 0.6944
# Epoch 53/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7430 - val_loss: 0.6563
# Epoch 54/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7463 - val_loss: 0.6403
# Epoch 55/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7365 - val_loss: 0.6621
# Epoch 56/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7272 - val_loss: 0.6514
# Epoch 57/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7418 - val_loss: 0.6499
# Epoch 58/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7282 - val_loss: 0.6498
# Epoch 59/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7294 - val_loss: 0.6554
# Epoch 60/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7178 - val_loss: 0.6395
# Epoch 61/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7246 - val_loss: 0.6765
# Epoch 62/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7303 - val_loss: 0.6536
# Epoch 63/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7183 - val_loss: 0.6360
# Epoch 64/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7156 - val_loss: 0.6534
# Epoch 65/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7156 - val_loss: 0.6360
# Epoch 66/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7087 - val_loss: 0.6467
# Epoch 67/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7073 - val_loss: 0.6451
# Epoch 68/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7082 - val_loss: 0.6603
# Epoch 69/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7016 - val_loss: 0.6395
# Epoch 70/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7037 - val_loss: 0.6173
# Epoch 71/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7036 - val_loss: 0.6365
# Epoch 72/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7032 - val_loss: 0.6465
# Epoch 73/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7005 - val_loss: 0.6431
# Epoch 74/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6968 - val_loss: 0.6349
# Epoch 75/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6920 - val_loss: 0.6166
# Epoch 76/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6894 - val_loss: 0.6383
# Epoch 77/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6873 - val_loss: 0.6260
# Epoch 78/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7035 - val_loss: 0.6274
# Epoch 79/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6859 - val_loss: 0.6311
# Epoch 80/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6909 - val_loss: 0.6476
# Epoch 81/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6877 - val_loss: 0.6121
# Epoch 82/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6868 - val_loss: 0.6345
# Epoch 83/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6871 - val_loss: 0.6168
# Epoch 84/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6809 - val_loss: 0.6035
# Epoch 85/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6804 - val_loss: 0.6247
# Epoch 86/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6751 - val_loss: 0.6017
# Epoch 87/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6712 - val_loss: 0.6087
# Epoch 88/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6706 - val_loss: 0.6067
# Epoch 89/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6720 - val_loss: 0.6199
# Epoch 90/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6719 - val_loss: 0.6229
# Epoch 91/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6817 - val_loss: 0.6217
# Epoch 92/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6680 - val_loss: 0.6056
# Epoch 93/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6623 - val_loss: 0.6253
# Epoch 94/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6587 - val_loss: 0.6155
# Epoch 95/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6654 - val_loss: 0.5963
# Epoch 96/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6536 - val_loss: 0.6162
# Epoch 97/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6621 - val_loss: 0.6064
# Epoch 98/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6584 - val_loss: 0.6171
# Epoch 99/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6561 - val_loss: 0.6088
# Epoch 100/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6594 - val_loss: 0.6152
# Epoch 101/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6561 - val_loss: 0.5925
# Epoch 102/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6518 - val_loss: 0.6112
# Epoch 103/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6508 - val_loss: 0.5974
# Epoch 104/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6425 - val_loss: 0.5807
# Epoch 105/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6534 - val_loss: 0.6016
# Epoch 106/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6491 - val_loss: 0.5957
# Epoch 107/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6430 - val_loss: 0.5977
# Epoch 108/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6441 - val_loss: 0.5863
# Epoch 109/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6446 - val_loss: 0.6254
# Epoch 110/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6384 - val_loss: 0.5969
# Epoch 111/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6420 - val_loss: 0.5843
# Epoch 112/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6322 - val_loss: 0.5820
# Epoch 113/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6417 - val_loss: 0.6174
# Epoch 114/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6402 - val_loss: 0.5955
# Epoch 115/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6315 - val_loss: 0.5988
# Epoch 116/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6360 - val_loss: 0.5928
# Epoch 117/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6392 - val_loss: 0.6017
# Epoch 118/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6322 - val_loss: 0.5866
# Epoch 119/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6449 - val_loss: 0.5948
# Epoch 120/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6294 - val_loss: 0.5843
# Epoch 121/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6228 - val_loss: 0.5973
# Epoch 122/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6219 - val_loss: 0.5925
# Epoch 123/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6330 - val_loss: 0.5799
# Epoch 124/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6249 - val_loss: 0.5722
# Epoch 125/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6309 - val_loss: 0.5998
# Epoch 126/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6309 - val_loss: 0.5961
# Epoch 127/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6234 - val_loss: 0.5877
# Epoch 128/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6262 - val_loss: 0.5753
# Epoch 129/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6193 - val_loss: 0.5687
# Epoch 130/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6208 - val_loss: 0.5659
# Epoch 131/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6207 - val_loss: 0.5634
# Epoch 132/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6176 - val_loss: 0.5887
# Epoch 133/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6219 - val_loss: 0.5841
# Epoch 134/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6179 - val_loss: 0.5775
# Epoch 135/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6224 - val_loss: 0.5609
# Epoch 136/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6191 - val_loss: 0.5797
# Epoch 137/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6300 - val_loss: 0.5811
# Epoch 138/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6186 - val_loss: 0.5909
# Epoch 139/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6311 - val_loss: 0.5735
# Epoch 140/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6198 - val_loss: 0.5708
# Epoch 141/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6089 - val_loss: 0.5686
# Epoch 142/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6188 - val_loss: 0.5638
# Epoch 143/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6193 - val_loss: 0.5783
# Epoch 144/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6102 - val_loss: 0.5685
# Epoch 145/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6213 - val_loss: 0.5743
# Epoch 146/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6149 - val_loss: 0.5711
# Epoch 147/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6056 - val_loss: 0.5668
# Epoch 148/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6053 - val_loss: 0.5733
# Epoch 149/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6083 - val_loss: 0.5726
# Epoch 150/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6073 - val_loss: 0.5849
# Epoch 151/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6260 - val_loss: 0.5814
# Epoch 152/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6061 - val_loss: 0.5564
# Epoch 153/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5998 - val_loss: 0.5863
# Epoch 154/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6013 - val_loss: 0.5640
# Epoch 155/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6278 - val_loss: 0.5638
# Epoch 156/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6040 - val_loss: 0.5715
# Epoch 157/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6035 - val_loss: 0.5641
# Epoch 158/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6042 - val_loss: 0.5684
# Epoch 159/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6043 - val_loss: 0.5723
# Epoch 160/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5999 - val_loss: 0.5517
# Epoch 161/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5939 - val_loss: 0.5627
# Epoch 162/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5959 - val_loss: 0.5772
# Epoch 163/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5919 - val_loss: 0.5522
# Epoch 164/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5916 - val_loss: 0.5559
# Epoch 165/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5930 - val_loss: 0.5746
# Epoch 166/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6083 - val_loss: 0.5771
# Epoch 167/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6214 - val_loss: 0.5750
# Epoch 168/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6024 - val_loss: 0.5582
# Epoch 169/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6024 - val_loss: 0.5616
# Epoch 170/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5906 - val_loss: 0.5538
# Epoch 171/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5989 - val_loss: 0.5595
# Epoch 172/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5920 - val_loss: 0.5598
# Epoch 173/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5907 - val_loss: 0.5547
# Epoch 174/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5852 - val_loss: 0.5589
# Epoch 175/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5892 - val_loss: 0.5631
# Epoch 176/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5906 - val_loss: 0.5487
# Epoch 177/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5904 - val_loss: 0.5606
# Epoch 178/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5887 - val_loss: 0.5466
# Epoch 179/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5889 - val_loss: 0.5889
# Epoch 180/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6107 - val_loss: 0.5639
# Epoch 181/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5954 - val_loss: 0.5560
# Epoch 182/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5857 - val_loss: 0.5778
# Epoch 183/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5866 - val_loss: 0.5601
# Epoch 184/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5948 - val_loss: 0.5651
# Epoch 185/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5860 - val_loss: 0.5377
# Epoch 186/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5858 - val_loss: 0.5609
# Epoch 187/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5844 - val_loss: 0.5603
# Epoch 188/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5911 - val_loss: 0.5537
# Epoch 189/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5867 - val_loss: 0.5698
# Epoch 190/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5892 - val_loss: 0.5534
# Epoch 191/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5863 - val_loss: 0.5632
# Epoch 192/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5783 - val_loss: 0.5528
# Epoch 193/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5892 - val_loss: 0.5563
# Epoch 194/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5833 - val_loss: 0.5538
# Epoch 195/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5794 - val_loss: 0.5516
# Epoch 196/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5763 - val_loss: 0.5461
# Epoch 197/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5759 - val_loss: 0.5423
# Epoch 198/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5805 - val_loss: 0.5405
# Epoch 199/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5808 - val_loss: 0.5590
# Epoch 200/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5848 - val_loss: 0.5442
# Epoch 201/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5733 - val_loss: 0.5437
# Epoch 202/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5785 - val_loss: 0.5380
# Epoch 203/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5807 - val_loss: 0.5588
# Epoch 204/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5724 - val_loss: 0.5428
# Epoch 205/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5701 - val_loss: 0.5424
# Epoch 206/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5809 - val_loss: 0.5565
# Epoch 207/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5878 - val_loss: 0.5498
# Epoch 208/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5727 - val_loss: 0.5348
# Epoch 209/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5688 - val_loss: 0.5540
# Epoch 210/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5751 - val_loss: 0.5397
# Epoch 211/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5663 - val_loss: 0.5589
# Epoch 212/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5707 - val_loss: 0.5338
# Epoch 213/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5701 - val_loss: 0.5598
# Epoch 214/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5685 - val_loss: 0.5599
# Epoch 215/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5682 - val_loss: 0.5293
# Epoch 216/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5645 - val_loss: 0.5547
# Epoch 217/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5651 - val_loss: 0.5636
# Epoch 218/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5679 - val_loss: 0.5426
# Epoch 219/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5733 - val_loss: 0.5363
# Epoch 220/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5685 - val_loss: 0.5679
# Epoch 221/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5717 - val_loss: 0.5469
# Epoch 222/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5645 - val_loss: 0.5421
# Epoch 223/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5698 - val_loss: 0.5412
# Epoch 224/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5650 - val_loss: 0.5425
# Epoch 225/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5617 - val_loss: 0.5334
# Epoch 226/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5785 - val_loss: 0.5416
# Epoch 227/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5610 - val_loss: 0.5420
# Epoch 228/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5607 - val_loss: 0.5672
# Epoch 229/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5634 - val_loss: 0.5296
# Epoch 230/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5595 - val_loss: 0.5323
# Epoch 231/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5577 - val_loss: 0.5554
# Epoch 232/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5623 - val_loss: 0.5453
# Epoch 233/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5602 - val_loss: 0.5304
# Epoch 234/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5543 - val_loss: 0.5653
# Epoch 235/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5614 - val_loss: 0.5415
# Epoch 236/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5586 - val_loss: 0.5250
# Epoch 237/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5572 - val_loss: 0.5406
# Epoch 238/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5667 - val_loss: 0.5426
# Epoch 239/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5895 - val_loss: 0.5430
# Epoch 240/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5588 - val_loss: 0.5554
# Epoch 241/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5607 - val_loss: 0.5419
# Epoch 242/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5544 - val_loss: 0.5352
# Epoch 243/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5552 - val_loss: 0.5447
# Epoch 244/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5511 - val_loss: 0.5449
# Epoch 245/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5622 - val_loss: 0.5266
# Epoch 246/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5515 - val_loss: 0.5310
# Epoch 247/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5571 - val_loss: 0.5758
# Epoch 248/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5588 - val_loss: 0.5601
# Epoch 249/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5563 - val_loss: 0.5302
# Epoch 250/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5480 - val_loss: 0.5360
# Epoch 251/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5566 - val_loss: 0.5341
# Epoch 252/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5530 - val_loss: 0.5456
# Epoch 253/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5466 - val_loss: 0.5284
# Epoch 254/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5588 - val_loss: 0.5393
# Epoch 255/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5498 - val_loss: 0.5340
# Epoch 256/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5539 - val_loss: 0.5302
# Epoch 257/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5455 - val_loss: 0.5256
# Epoch 258/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5490 - val_loss: 0.5575
# Epoch 259/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5438 - val_loss: 0.5250
# Epoch 260/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5491 - val_loss: 0.5312
# Epoch 261/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5552 - val_loss: 0.5457
# Epoch 262/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5938 - val_loss: 0.5250
# Epoch 263/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5589 - val_loss: 0.5317
# Epoch 264/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5533 - val_loss: 0.5676
# Epoch 265/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5569 - val_loss: 0.5323
# Epoch 266/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5697 - val_loss: 0.5232
# Epoch 267/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5503 - val_loss: 0.5303
# Epoch 268/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5501 - val_loss: 0.5228
# Epoch 269/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5551 - val_loss: 0.5731
# Epoch 270/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5582 - val_loss: 0.5336
# Epoch 271/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5467 - val_loss: 0.5277
# Epoch 272/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5458 - val_loss: 0.5310
# Epoch 273/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5495 - val_loss: 0.5268
# Epoch 274/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5580 - val_loss: 0.5285
# Epoch 275/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5448 - val_loss: 0.5310
# Epoch 276/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6008 - val_loss: 0.5902
# Epoch 277/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5941 - val_loss: 0.5331
# Epoch 278/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5608 - val_loss: 0.5316
# Epoch 279/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5510 - val_loss: 0.5213
# Epoch 280/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5507 - val_loss: 0.5384
# Epoch 281/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5507 - val_loss: 0.5315
# Epoch 282/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5504 - val_loss: 0.5325
# Epoch 283/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5495 - val_loss: 0.5138
# Epoch 284/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5409 - val_loss: 0.5421
# Epoch 285/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5518 - val_loss: 0.5157
# Epoch 286/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5435 - val_loss: 0.5191
# Epoch 287/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5471 - val_loss: 0.5209
# Epoch 288/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5366 - val_loss: 0.5435
# Epoch 289/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5417 - val_loss: 0.5243
# Epoch 290/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5397 - val_loss: 0.5170
# Epoch 291/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5393 - val_loss: 0.5230
# Epoch 292/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5413 - val_loss: 0.5266
# Epoch 293/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5909 - val_loss: 0.5415
# Epoch 294/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5731 - val_loss: 0.5298
# Epoch 295/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5432 - val_loss: 0.5385
# Epoch 296/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5462 - val_loss: 0.5175
# Epoch 297/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5389 - val_loss: 0.5176
# Epoch 298/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5446 - val_loss: 0.5229
# Epoch 299/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5384 - val_loss: 0.5155
# Epoch 300/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5388 - val_loss: 0.5331
# Epoch 301/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5358 - val_loss: 0.5129
# Epoch 302/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5365 - val_loss: 0.5097
# Epoch 303/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5331 - val_loss: 0.5147
# Epoch 304/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5346 - val_loss: 0.5338
# Epoch 305/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5359 - val_loss: 0.5440
# Epoch 306/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5378 - val_loss: 0.5345
# Epoch 307/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5375 - val_loss: 0.5200
# Epoch 308/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5417 - val_loss: 0.5181
# Epoch 309/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5374 - val_loss: 0.5216
# Epoch 310/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5331 - val_loss: 0.5207
# Epoch 311/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5476 - val_loss: 0.5166
# Epoch 312/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5333 - val_loss: 0.5149
# Epoch 313/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5295 - val_loss: 0.5260
# Epoch 314/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5320 - val_loss: 0.5209
# Epoch 315/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5327 - val_loss: 0.5323
# Epoch 316/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5272 - val_loss: 0.5307
# Epoch 317/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5365 - val_loss: 0.5311
# Epoch 318/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5334 - val_loss: 0.5331
# Epoch 319/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5271 - val_loss: 0.5199
# Epoch 320/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5313 - val_loss: 0.5201
# Epoch 321/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6532 - val_loss: 0.5600
# Epoch 322/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.6067 - val_loss: 0.5516
# Epoch 323/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5841 - val_loss: 0.5767
# Epoch 324/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5755 - val_loss: 0.5273
# Epoch 325/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5636 - val_loss: 0.5200
# Epoch 326/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5500 - val_loss: 0.5033
# Epoch 327/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5393 - val_loss: 0.5218
# Epoch 328/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5476 - val_loss: 0.5075
# Epoch 329/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5428 - val_loss: 0.5045
# Epoch 330/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5383 - val_loss: 0.5105
# Epoch 331/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5320 - val_loss: 0.5164
# Epoch 332/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5389 - val_loss: 0.5069
# Epoch 333/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5323 - val_loss: 0.5208
# Epoch 334/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5262 - val_loss: 0.5131
# Epoch 335/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5292 - val_loss: 0.5129
# Epoch 336/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5300 - val_loss: 0.4960
# Epoch 337/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5272 - val_loss: 0.5238
# Epoch 338/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5375 - val_loss: 0.5054
# Epoch 339/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5848 - val_loss: 0.5443
# Epoch 340/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5616 - val_loss: 0.5292
# Epoch 341/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5558 - val_loss: 0.5192
# Epoch 342/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5534 - val_loss: 0.5224
# Epoch 343/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5504 - val_loss: 0.5056
# Epoch 344/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5455 - val_loss: 0.5170
# Epoch 345/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5507 - val_loss: 0.5133
# Epoch 346/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5426 - val_loss: 0.5127
# Epoch 347/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5483 - val_loss: 0.5103
# Epoch 348/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5444 - val_loss: 0.5165
# Epoch 349/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5433 - val_loss: 0.5056
# Epoch 350/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5380 - val_loss: 0.5139
# Epoch 351/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5401 - val_loss: 0.5081
# Epoch 352/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5383 - val_loss: 0.5090
# Epoch 353/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5384 - val_loss: 0.4995
# Epoch 354/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5310 - val_loss: 0.5003
# Epoch 355/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5342 - val_loss: 0.4993
# Epoch 356/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5383 - val_loss: 0.5103
# Epoch 357/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5434 - val_loss: 0.5111
# Epoch 358/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5396 - val_loss: 0.5165
# Epoch 359/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5351 - val_loss: 0.5231
# Epoch 360/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5344 - val_loss: 0.5050
# Epoch 361/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5427 - val_loss: 0.5227
# Epoch 362/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5339 - val_loss: 0.4974
# Epoch 363/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5393 - val_loss: 0.4942
# Epoch 364/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5321 - val_loss: 0.4927
# Epoch 365/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5279 - val_loss: 0.4952
# Epoch 366/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5377 - val_loss: 0.4994
# Epoch 367/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5301 - val_loss: 0.4904
# Epoch 368/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5337 - val_loss: 0.5186
# Epoch 369/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5346 - val_loss: 0.4987
# Epoch 370/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5299 - val_loss: 0.4995
# Epoch 371/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5311 - val_loss: 0.5191
# Epoch 372/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5304 - val_loss: 0.5169
# Epoch 373/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5312 - val_loss: 0.5051
# Epoch 374/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5306 - val_loss: 0.5086
# Epoch 375/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5352 - val_loss: 0.5040
# Epoch 376/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5303 - val_loss: 0.4965
# Epoch 377/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5293 - val_loss: 0.5107
# Epoch 378/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5226 - val_loss: 0.5141
# Epoch 379/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5187 - val_loss: 0.5007
# Epoch 380/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5235 - val_loss: 0.5048
# Epoch 381/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5259 - val_loss: 0.4975
# Epoch 382/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5290 - val_loss: 0.5000
# Epoch 383/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5302 - val_loss: 0.4896
# Epoch 384/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5242 - val_loss: 0.4941
# Epoch 385/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5180 - val_loss: 0.4893
# Epoch 386/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5143 - val_loss: 0.4927
# Epoch 387/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5208 - val_loss: 0.4886
# Epoch 388/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5196 - val_loss: 0.5069
# Epoch 389/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5192 - val_loss: 0.4924
# Epoch 390/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5180 - val_loss: 0.5135
# Epoch 391/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5272 - val_loss: 0.4889
# Epoch 392/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5254 - val_loss: 0.4941
# Epoch 393/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5250 - val_loss: 0.4855
# Epoch 394/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5185 - val_loss: 0.4991
# Epoch 395/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5193 - val_loss: 0.4869
# Epoch 396/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5174 - val_loss: 0.4821
# Epoch 397/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5154 - val_loss: 0.4849
# Epoch 398/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5226 - val_loss: 0.4967
# Epoch 399/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5202 - val_loss: 0.4938
# Epoch 400/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5184 - val_loss: 0.5013
# Epoch 401/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5206 - val_loss: 0.4869
# Epoch 402/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5143 - val_loss: 0.4834
# Epoch 403/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5234 - val_loss: 0.5091
# Epoch 404/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5213 - val_loss: 0.4971
# Epoch 405/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5200 - val_loss: 0.4942
# Epoch 406/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5178 - val_loss: 0.5208
# Epoch 407/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5133 - val_loss: 0.4871
# Epoch 408/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5176 - val_loss: 0.4844
# Epoch 409/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5153 - val_loss: 0.5191
# Epoch 410/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5163 - val_loss: 0.5102
# Epoch 411/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5163 - val_loss: 0.4824
# Epoch 412/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5142 - val_loss: 0.4917
# Epoch 413/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5126 - val_loss: 0.4927
# Epoch 414/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5113 - val_loss: 0.4938
# Epoch 415/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5230 - val_loss: 0.4952
# Epoch 416/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5095 - val_loss: 0.4817
# Epoch 417/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5104 - val_loss: 0.4764
# Epoch 418/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5111 - val_loss: 0.4870
# Epoch 419/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5093 - val_loss: 0.4769
# Epoch 420/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5221 - val_loss: 0.4763
# Epoch 421/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5131 - val_loss: 0.4815
# Epoch 422/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5118 - val_loss: 0.4874
# Epoch 423/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5074 - val_loss: 0.4802
# Epoch 424/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5166 - val_loss: 0.4761
# Epoch 425/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5146 - val_loss: 0.4752
# Epoch 426/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5117 - val_loss: 0.4770
# Epoch 427/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5123 - val_loss: 0.4913
# Epoch 428/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5144 - val_loss: 0.4846
# Epoch 429/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5128 - val_loss: 0.4725
# Epoch 430/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5189 - val_loss: 0.4767
# Epoch 431/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5172 - val_loss: 0.4938
# Epoch 432/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5147 - val_loss: 0.4793
# Epoch 433/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5161 - val_loss: 0.4765
# Epoch 434/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5061 - val_loss: 0.4698
# Epoch 435/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5186 - val_loss: 0.4795
# Epoch 436/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5134 - val_loss: 0.4958
# Epoch 437/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5172 - val_loss: 0.4899
# Epoch 438/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5102 - val_loss: 0.4932
# Epoch 439/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5183 - val_loss: 0.4811
# Epoch 440/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5131 - val_loss: 0.4878
# Epoch 441/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5165 - val_loss: 0.5057
# Epoch 442/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5124 - val_loss: 0.4803
# Epoch 443/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5135 - val_loss: 0.4798
# Epoch 444/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5141 - val_loss: 0.4763
# Epoch 445/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5126 - val_loss: 0.4718
# Epoch 446/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5097 - val_loss: 0.4820
# Epoch 447/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5122 - val_loss: 0.4804
# Epoch 448/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5042 - val_loss: 0.4715
# Epoch 449/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5065 - val_loss: 0.4700
# Epoch 450/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5164 - val_loss: 0.4899
# Epoch 451/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5098 - val_loss: 0.4824
# Epoch 452/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5060 - val_loss: 0.4787
# Epoch 453/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5101 - val_loss: 0.4650
# Epoch 454/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5069 - val_loss: 0.4694
# Epoch 455/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5032 - val_loss: 0.4830
# Epoch 456/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5060 - val_loss: 0.4748
# Epoch 457/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5043 - val_loss: 0.4669
# Epoch 458/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5031 - val_loss: 0.4597
# Epoch 459/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5060 - val_loss: 0.4735
# Epoch 460/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5039 - val_loss: 0.4835
# Epoch 461/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5101 - val_loss: 0.4817
# Epoch 462/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5050 - val_loss: 0.4665
# Epoch 463/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5106 - val_loss: 0.4639
# Epoch 464/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5078 - val_loss: 0.4671
# Epoch 465/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5063 - val_loss: 0.4836
# Epoch 466/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5067 - val_loss: 0.4784
# Epoch 467/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5048 - val_loss: 0.4630
# Epoch 468/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5017 - val_loss: 0.4773
# Epoch 469/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5001 - val_loss: 0.4730
# Epoch 470/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5047 - val_loss: 0.4837
# Epoch 471/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5087 - val_loss: 0.4809
# Epoch 472/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5053 - val_loss: 0.4665
# Epoch 473/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5042 - val_loss: 0.4724
# Epoch 474/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5089 - val_loss: 0.4826
# Epoch 475/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5022 - val_loss: 0.4792
# Epoch 476/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5032 - val_loss: 0.4737
# Epoch 477/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4969 - val_loss: 0.4692
# Epoch 478/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4981 - val_loss: 0.4590
# Epoch 479/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5005 - val_loss: 0.4584
# Epoch 480/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5028 - val_loss: 0.4627
# Epoch 481/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4992 - val_loss: 0.4577
# Epoch 482/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4991 - val_loss: 0.4813
# Epoch 483/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5016 - val_loss: 0.4693
# Epoch 484/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5029 - val_loss: 0.4608
# Epoch 485/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5060 - val_loss: 0.4663
# Epoch 486/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4983 - val_loss: 0.4884
# Epoch 487/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4990 - val_loss: 0.4527
# Epoch 488/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4959 - val_loss: 0.4663
# Epoch 489/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4987 - val_loss: 0.4782
# Epoch 490/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4951 - val_loss: 0.4633
# Epoch 491/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4988 - val_loss: 0.4726
# Epoch 492/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4967 - val_loss: 0.4616
# Epoch 493/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5033 - val_loss: 0.4541
# Epoch 494/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4974 - val_loss: 0.4655
# Epoch 495/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4956 - val_loss: 0.4551
# Epoch 496/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5007 - val_loss: 0.4556
# Epoch 497/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4951 - val_loss: 0.4756
# Epoch 498/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5019 - val_loss: 0.4685
# Epoch 499/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4922 - val_loss: 0.4687
# Epoch 500/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5008 - val_loss: 0.4772
# Epoch 501/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4957 - val_loss: 0.4876
# Epoch 502/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5030 - val_loss: 0.4743
# Epoch 503/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5037 - val_loss: 0.4735
# Epoch 504/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4944 - val_loss: 0.4646
# Epoch 505/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4955 - val_loss: 0.4569
# Epoch 506/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4956 - val_loss: 0.4655
# Epoch 507/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4971 - val_loss: 0.4607
# Epoch 508/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4950 - val_loss: 0.4597
# Epoch 509/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4946 - val_loss: 0.4617
# Epoch 510/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4976 - val_loss: 0.4837
# Epoch 511/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4953 - val_loss: 0.4602
# Epoch 512/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4915 - val_loss: 0.4697
# Epoch 513/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4945 - val_loss: 0.4557
# Epoch 514/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4924 - val_loss: 0.4512
# Epoch 515/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4959 - val_loss: 0.4415
# Epoch 516/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4954 - val_loss: 0.4751
# Epoch 517/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4915 - val_loss: 0.4723
# Epoch 518/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4905 - val_loss: 0.4640
# Epoch 519/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4900 - val_loss: 0.4550
# Epoch 520/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4957 - val_loss: 0.4990
# Epoch 521/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4978 - val_loss: 0.4717
# Epoch 522/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4939 - val_loss: 0.4663
# Epoch 523/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4933 - val_loss: 0.4637
# Epoch 524/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4961 - val_loss: 0.4469
# Epoch 525/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4935 - val_loss: 0.4541
# Epoch 526/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4933 - val_loss: 0.4545
# Epoch 527/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4900 - val_loss: 0.4551
# Epoch 528/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4932 - val_loss: 0.4566
# Epoch 529/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4938 - val_loss: 0.4550
# Epoch 530/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4932 - val_loss: 0.4665
# Epoch 531/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4898 - val_loss: 0.4651
# Epoch 532/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4946 - val_loss: 0.4610
# Epoch 533/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4870 - val_loss: 0.4577
# Epoch 534/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4879 - val_loss: 0.4857
# Epoch 535/1000
# ...
# Epoch 644/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4806 - val_loss: 0.4393
# Epoch 645/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4726 - val_loss: 0.4528
# Epoch 646/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4746 - val_loss: 0.4506
# Epoch 647/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4754 - val_loss: 0.4420
# Epoch 648/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4744 - val_loss: 0.4425
# Epoch 649/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4676 - val_loss: 0.4354
# Epoch 650/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4761 - val_loss: 0.4379
# Epoch 651/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4733 - val_loss: 0.4344
# Epoch 652/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4720 - val_loss: 0.4357
# Epoch 653/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4777 - val_loss: 0.4383
# Epoch 654/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4694 - val_loss: 0.4352
# Epoch 655/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4724 - val_loss: 0.4448
# Epoch 656/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4701 - val_loss: 0.4528
# Epoch 657/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4723 - val_loss: 0.4426
# Epoch 658/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4796 - val_loss: 0.4494
# Epoch 659/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4689 - val_loss: 0.4506
# Epoch 660/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4720 - val_loss: 0.4490
# Epoch 661/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4737 - val_loss: 0.4384
# Epoch 662/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4695 - val_loss: 0.4370
# Epoch 663/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4662 - val_loss: 0.4461
# Epoch 664/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4775 - val_loss: 0.4608
# Epoch 665/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4746 - val_loss: 0.4541
# Epoch 666/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4764 - val_loss: 0.4461
# Epoch 667/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4751 - val_loss: 0.4404
# Epoch 668/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4774 - val_loss: 0.4345
# Epoch 669/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4678 - val_loss: 0.4439
# Epoch 670/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4716 - val_loss: 0.4556
# Epoch 671/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4759 - val_loss: 0.4488
# Epoch 672/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4670 - val_loss: 0.4483
# Epoch 673/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4749 - val_loss: 0.4287
# Epoch 674/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4732 - val_loss: 0.4354
# Epoch 675/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4732 - val_loss: 0.4419
# Epoch 676/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4667 - val_loss: 0.4458
# Epoch 677/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4733 - val_loss: 0.4357
# Epoch 678/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4715 - val_loss: 0.4497
# Epoch 679/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4730 - val_loss: 0.4286
# Epoch 680/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4616 - val_loss: 0.4495
# Epoch 681/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4722 - val_loss: 0.4352
# Epoch 682/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4682 - val_loss: 0.4322
# Epoch 683/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4704 - val_loss: 0.4594
# Epoch 684/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4704 - val_loss: 0.4369
# Epoch 685/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4697 - val_loss: 0.4334
# Epoch 686/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4643 - val_loss: 0.4450
# Epoch 687/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4669 - val_loss: 0.4364
# Epoch 688/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4674 - val_loss: 0.4374
# Epoch 689/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4643 - val_loss: 0.4460
# Epoch 690/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4714 - val_loss: 0.4476
# Epoch 691/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4668 - val_loss: 0.4401
# Epoch 692/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4742 - val_loss: 0.4504
# Epoch 693/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4731 - val_loss: 0.4319
# Epoch 694/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4687 - val_loss: 0.4263
# Epoch 695/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4680 - val_loss: 0.4425
# Epoch 696/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4733 - val_loss: 0.4308
# Epoch 697/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4667 - val_loss: 0.4500
# Epoch 698/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4664 - val_loss: 0.4436
# Epoch 699/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4719 - val_loss: 0.4477
# Epoch 700/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4679 - val_loss: 0.4308
# Epoch 701/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4657 - val_loss: 0.4700
# Epoch 702/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4726 - val_loss: 0.4367
# Epoch 703/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4734 - val_loss: 0.4455
# Epoch 704/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4640 - val_loss: 0.4489
# Epoch 705/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4689 - val_loss: 0.4504
# Epoch 706/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4707 - val_loss: 0.4439
# Epoch 707/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4751 - val_loss: 0.4604
# Epoch 708/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4689 - val_loss: 0.4329
# Epoch 709/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4644 - val_loss: 0.4473
# Epoch 710/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4662 - val_loss: 0.4332
# Epoch 711/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4630 - val_loss: 0.4383
# Epoch 712/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4717 - val_loss: 0.4318
# Epoch 713/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4627 - val_loss: 0.4604
# Epoch 714/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4640 - val_loss: 0.4245
# Epoch 715/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4606 - val_loss: 0.4309
# Epoch 716/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4633 - val_loss: 0.4365
# Epoch 717/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4658 - val_loss: 0.4373
# Epoch 718/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4714 - val_loss: 0.4511
# Epoch 719/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4694 - val_loss: 0.4335
# Epoch 720/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4712 - val_loss: 0.4301
# Epoch 721/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4674 - val_loss: 0.4412
# Epoch 722/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4688 - val_loss: 0.4430
# Epoch 723/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4647 - val_loss: 0.4399
# Epoch 724/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4662 - val_loss: 0.4265
# Epoch 725/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4673 - val_loss: 0.4426
# Epoch 726/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4660 - val_loss: 0.4472
# Epoch 727/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4599 - val_loss: 0.4370
# Epoch 728/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4632 - val_loss: 0.4392
# Epoch 729/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4635 - val_loss: 0.4421
# Epoch 730/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4666 - val_loss: 0.4479
# Epoch 731/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4661 - val_loss: 0.4623
# Epoch 732/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4618 - val_loss: 0.4395
# Epoch 733/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4645 - val_loss: 0.4410
# Epoch 734/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4648 - val_loss: 0.4276
# Epoch 735/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4688 - val_loss: 0.4334
# Epoch 736/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4630 - val_loss: 0.4340
# Epoch 737/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4582 - val_loss: 0.4344
# Epoch 738/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4625 - val_loss: 0.4410
# Epoch 739/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4633 - val_loss: 0.4320
# Epoch 740/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4567 - val_loss: 0.4333
# Epoch 741/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4621 - val_loss: 0.4335
# Epoch 742/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4644 - val_loss: 0.4391
# Epoch 743/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4613 - val_loss: 0.4274
# Epoch 744/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4630 - val_loss: 0.4547
# Epoch 745/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4636 - val_loss: 0.4232
# Epoch 746/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4641 - val_loss: 0.4640
# Epoch 747/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4649 - val_loss: 0.4293
# Epoch 748/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4687 - val_loss: 0.4354
# Epoch 749/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4639 - val_loss: 0.4280
# Epoch 750/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4595 - val_loss: 0.4319
# Epoch 751/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4614 - val_loss: 0.4446
# Epoch 752/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4615 - val_loss: 0.4689
# Epoch 753/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4681 - val_loss: 0.4587
# Epoch 754/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4656 - val_loss: 0.4300
# Epoch 755/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4586 - val_loss: 0.4182
# Epoch 756/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4659 - val_loss: 0.4286
# Epoch 757/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4585 - val_loss: 0.4206
# Epoch 758/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4674 - val_loss: 0.4561
# Epoch 759/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4594 - val_loss: 0.4391
# Epoch 760/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4620 - val_loss: 0.4421
# Epoch 761/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4557 - val_loss: 0.4389
# Epoch 762/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4566 - val_loss: 0.4324
# Epoch 763/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.4594 - val_loss: 0.4513
# Epoch 764/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.4585 - val_loss: 0.4261
# Epoch 765/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.4633 - val_loss: 0.4249
# Epoch 766/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4632 - val_loss: 0.4251
# Epoch 767/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4615 - val_loss: 0.4257
# Epoch 768/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4620 - val_loss: 0.4274
# Epoch 769/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4584 - val_loss: 0.4357
# Epoch 770/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.4655 - val_loss: 0.4705
# Epoch 771/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4620 - val_loss: 0.4370
# Epoch 772/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4572 - val_loss: 0.4228
# Epoch 773/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4601 - val_loss: 0.4470
# Epoch 774/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4673 - val_loss: 0.4389
# Epoch 775/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4581 - val_loss: 0.4379
# Epoch 776/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4627 - val_loss: 0.4355
# Epoch 777/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4565 - val_loss: 0.4349
# Epoch 778/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4581 - val_loss: 0.4310
# Epoch 779/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4537 - val_loss: 0.4207
# Epoch 780/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.4625 - val_loss: 0.4326
# Epoch 781/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4646 - val_loss: 0.4311
# Epoch 782/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4605 - val_loss: 0.4269
# Epoch 783/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4583 - val_loss: 0.4369
# Epoch 784/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4614 - val_loss: 0.4427
# Epoch 785/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4599 - val_loss: 0.4354
# Epoch 786/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4573 - val_loss: 0.4326
# Epoch 787/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4606 - val_loss: 0.4355
# Epoch 788/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4532 - val_loss: 0.4335
# Epoch 789/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4575 - val_loss: 0.4271
# Epoch 790/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4541 - val_loss: 0.4415
# Epoch 791/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4552 - val_loss: 0.4496
# Epoch 792/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.4574 - val_loss: 0.4341
# Epoch 793/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.4558 - val_loss: 0.4329
# Epoch 794/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.4563 - val_loss: 0.4363
# Epoch 795/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.4551 - val_loss: 0.4228
# Epoch 796/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4559 - val_loss: 0.4236
# Epoch 797/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4644 - val_loss: 0.4298
# Epoch 798/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4553 - val_loss: 0.4293
# Epoch 799/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4540 - val_loss: 0.4334
# Epoch 800/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4575 - val_loss: 0.4202
# Epoch 801/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4579 - val_loss: 0.4535
# Epoch 802/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4648 - val_loss: 0.4282
# Epoch 803/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4583 - val_loss: 0.4289
# Epoch 804/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4541 - val_loss: 0.4184
# Epoch 805/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4552 - val_loss: 0.4284
# Epoch 806/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4575 - val_loss: 0.4472
# Epoch 807/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4562 - val_loss: 0.4492
# Epoch 808/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4612 - val_loss: 0.4636
# Epoch 809/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4625 - val_loss: 0.4306
# Epoch 810/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4608 - val_loss: 0.4213
# Epoch 811/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4547 - val_loss: 0.4304
# Epoch 812/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4586 - val_loss: 0.4220
# Epoch 813/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4637 - val_loss: 0.4248
# Epoch 814/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4546 - val_loss: 0.4372
# Epoch 815/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4540 - val_loss: 0.4149
# Epoch 816/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4578 - val_loss: 0.4264
# Epoch 817/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4615 - val_loss: 0.4419
# Epoch 818/1000
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.4522 - val_loss: 0.4229
# Epoch 819/1000
#  13/117 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4223
